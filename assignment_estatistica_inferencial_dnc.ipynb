# %% [markdown]
# <a href="https://colab.research.google.com/github/nessamariano/assignment-estatista-inferencial-DNC/blob/main/assignment_estatistica_inferencial_dnc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assingment de Estatística Inferencial

# %% [markdown]
# Aluna: Vanessa Mariano da Silva

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
#from sklearn import datasets

# %% [markdown]
# Lendo o arquivo csv disponibilizado no .zip

# %%
iris_df = pd.read_csv("https://raw.githubusercontent.com/nessamariano/assignment-estatista-inferencial-DNC/main/iris.csv")

# ou lendo direto 
#iris_df = pd.DataFrame(datasets.load_iris().data)
#iris_df.columns = datasets.load_iris().feature_names

# %%
iris_df.shape
# Out:
# (150, 7)

# %% [markdown]
# O arquivo possui 150 linhas e 7 colunas

# %%
iris_df.head() # exibindo as 5 primeiras linhas e conhecendo o dataset
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           0                5.1               3.5                1.4
# 1           1                4.9               3.0                1.4
# 2           2                4.7               3.2                1.3
# 3           3                4.6               3.1                1.5
# 4           4                5.0               3.6                1.4
#
#    petal width (cm)  target target_name
# 0               0.2       0      setosa
# 1               0.2       0      setosa
# 2               0.2       0      setosa
# 3               0.2       0      setosa
# 4               0.2       0      setosa

# %% [markdown]
# Levantando informações sobre dados nulos e tipos de variáveis

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         150 non-null    int64
#  1   sepal length (cm)  150 non-null    float64
#  2   sepal width (cm)   150 non-null    float64
#  3   petal length (cm)  150 non-null    float64
#  4   petal width (cm)   150 non-null    float64
#  5   target             150 non-null    int64
#  6   target_name        150 non-null    object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 8.3+ KB

# %%
iris_df.set_index('Unnamed: 0', inplace=True)

# %%
iris_df.head()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Unnamed: 0
# 0                         5.1               3.5                1.4
# 1                         4.9               3.0                1.4
# 2                         4.7               3.2                1.3
# 3                         4.6               3.1                1.5
# 4                         5.0               3.6                1.4
#
#             petal width (cm)  target target_name
# Unnamed: 0
# 0                        0.2       0      setosa
# 1                        0.2       0      setosa
# 2                        0.2       0      setosa
# 3                        0.2       0      setosa
# 4                        0.2       0      setosa

# %% [markdown]
# Amostragem aleatória simples com 20 amostras

# %%
# Método de Amostragem
n_amostra = 20
n_iris = iris_df.shape

# %%
# Amostragem Simples (Amostra totalmente aleatória)
simples = iris_df.sample(n_amostra)

# %%
simples
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Unnamed: 0
# 100                       6.3               3.3                6.0
# 108                       6.7               2.5                5.8
# 120                       6.9               3.2                5.7
# 74                        6.4               2.9                4.3
# 136                       6.3               3.4                5.6
# 102                       7.1               3.0                5.9
# 17                        5.1               3.5                1.4
# 27                        5.2               3.5                1.5
# 69                        5.6               2.5                3.9
# 60                        5.0               2.0                3.5
# 129                       7.2               3.0                5.8
# 104                       6.5               3.0                5.8
# 41                        4.5               2.3                1.3
# ...

# %% [markdown]
# Amostragem de Julgamento

# %% [markdown]
# Itens com 'petal width' maior que 2.0 cm

# %%
amostra_julg = iris_df.loc[(iris_df['petal width (cm)'] >  2.0 )]
amostra_julg.shape
# Out:
# (23, 6)

# %%
amostra_julg

# todas as amostras são da espécie Virginica
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Unnamed: 0
# 100                       6.3               3.3                6.0
# 102                       7.1               3.0                5.9
# 104                       6.5               3.0                5.8
# 105                       7.6               3.0                6.6
# 109                       7.2               3.6                6.1
# 112                       6.8               3.0                5.5
# 114                       5.8               2.8                5.1
# 115                       6.4               3.2                5.3
# 117                       7.7               3.8                6.7
# 118                       7.7               2.6                6.9
# 120                       6.9               3.2                5.7
# 124                       6.7               3.3                5.7
# 128                       6.4               2.8                5.6
# ...

# %% [markdown]
# Amostra de conveniência
#
# Primeiros 30 itens

# %%
iris_df.head(30)
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Unnamed: 0
# 0                         5.1               3.5                1.4
# 1                         4.9               3.0                1.4
# 2                         4.7               3.2                1.3
# 3                         4.6               3.1                1.5
# 4                         5.0               3.6                1.4
# 5                         5.4               3.9                1.7
# 6                         4.6               3.4                1.4
# 7                         5.0               3.4                1.5
# 8                         4.4               2.9                1.4
# 9                         4.9               3.1                1.5
# 10                        5.4               3.7                1.5
# 11                        4.8               3.4                1.6
# 12                        4.8               3.0                1.4
# ...
